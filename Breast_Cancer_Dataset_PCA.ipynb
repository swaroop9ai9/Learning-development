# %% [markdown]
# # Principal Component Analysis with Cancer Data

# %%
#Import all the necessary modules
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import zscore
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Q1. Load the Data file ( Breast Cancer CSV) into Python DataFrame and view top 10 rows

# %%
cancer_df = pd.read_csv('breast-cancer-wisconsin-data.csv')

# %%
  # Id columns is to identify rows hence can be skipped in analysis
  # All columns have numerical values
  # Class would be the target variable. Should be removed when PCA is done

# %%
features_df = cancer_df.drop(['ID'], axis = 1)

# %%
features_df.head()
# Out:
#    ClumpThickness  Cell Size  Cell Shape  Marginal Adhesion  \
# 0               5          1           1                  1
# 1               5          4           4                  5
# 2               3          1           1                  1
# 3               6          8           8                  1
# 4               4          1           1                  3
#
#    Single Epithelial Cell Size Bare Nuclei  Normal Nucleoli  Bland Chromatin  \
# 0                            2           1                3                1
# 1                            7          10                3                2
# 2                            2           2                3                1
# 3                            3           4                3                7
# 4                            2           1                3                1
#
#    Mitoses  Class
# 0        1      2
# 1        1      2
# 2        1      2
# 3        1      2
# 4        1      2

# %% [markdown]
# # Q2 Print the datatypes of each column and the shape of the dataset. Perform descriptive analysis

# %%
features_df.dtypes
# Out:
# ClumpThickness                  int64
# Cell Size                       int64
# Cell Shape                      int64
# Marginal Adhesion               int64
# Single Epithelial Cell Size     int64
# Bare Nuclei                    object
# Normal Nucleoli                 int64
# Bland Chromatin                 int64
# Mitoses                         int64
# Class                           int64
# dtype: object

# %%
features_df.describe().T
# Out:
#                              count      mean       std  min  25%  50%  75%  \
# ClumpThickness               699.0  4.417740  2.815741  1.0  2.0  4.0  6.0
# Cell Size                    699.0  3.134478  3.051459  1.0  1.0  1.0  5.0
# Cell Shape                   699.0  3.207439  2.971913  1.0  1.0  1.0  5.0
# Marginal Adhesion            699.0  2.806867  2.855379  1.0  1.0  1.0  4.0
# Single Epithelial Cell Size  699.0  3.216023  2.214300  1.0  2.0  2.0  4.0
# Normal Nucleoli              699.0  3.437768  2.438364  1.0  2.0  3.0  5.0
# Bland Chromatin              699.0  2.866953  3.053634  1.0  1.0  1.0  4.0
# Mitoses                      699.0  1.589413  1.715078  1.0  1.0  1.0  1.0
# Class                        699.0  2.689557  0.951273  2.0  2.0  2.0  4.0
#
#                               max
# ClumpThickness               10.0
# Cell Size                    10.0
# Cell Shape                   10.0
# Marginal Adhesion            10.0
# Single Epithelial Cell Size  10.0
# Normal Nucleoli              10.0
# Bland Chromatin              10.0
# Mitoses                      10.0
# Class                         4.0

# %% [markdown]
# # Q3 Check for missing value check, incorrect data, duplicate data and perform imputation with mean, median, mode as necessary.

# %%
# We could see "?" values in column, this should be removed from data set

# Check for missing value in any other column

# %%
# No missing values found. So let us try to remove ? from bare nuclei column

# Get count of rows having ?

# %%
# 16 values are corrupted. We can either delete them as it forms roughly 2% of data.
# Here we would like to impute it with suitable values

# %%
features_df.isnull().sum()
# Out:
# ClumpThickness                 0
# Cell Size                      0
# Cell Shape                     0
# Marginal Adhesion              0
# Single Epithelial Cell Size    0
# Bare Nuclei                    0
# Normal Nucleoli                0
# Bland Chromatin                0
# Mitoses                        0
# Class                          0
# dtype: int64

# %%
filter1 = features_df['Bare Nuclei'] == '?'

# %%
features_df[filter1].shape
# Out:
# (16, 10)

# %%
features_df.loc[filter1, 'Bare Nuclei'] = np.nan

# %%
features_df.isnull().sum()
# Out:
# ClumpThickness                  0
# Cell Size                       0
# Cell Shape                      0
# Marginal Adhesion               0
# Single Epithelial Cell Size     0
# Bare Nuclei                    16
# Normal Nucleoli                 0
# Bland Chromatin                 0
# Mitoses                         0
# Class                           0
# dtype: int64

# %%
features_df = features_df.apply(lambda x: x.fillna(x.median()),axis=1)

# %%
features_df.isnull().sum()
# Out:
# ClumpThickness                 0
# Cell Size                      0
# Cell Shape                     0
# Marginal Adhesion              0
# Single Epithelial Cell Size    0
# Bare Nuclei                    0
# Normal Nucleoli                0
# Bland Chromatin                0
# Mitoses                        0
# Class                          0
# dtype: int64

# %%
features_df.shape
# Out:
# (699, 10)

# %%
features_df.duplicated(keep='first').sum()
# Out:
# 236

# %%
features_df.drop_duplicates(keep = 'first', inplace = True)

# %%
features_df.shape
# Out:
# (463, 10)

# %%
features_df['Bare Nuclei'] = features_df['Bare Nuclei'].astype('float64')

# %% [markdown]
# # Q4. Perform bi variate analysis including correlation, pairplots and state the inferences.

# %%
# Check for correlation of variable

# %%
# Cell size shows high significance with cell shape,marginal adhesion, single epithelial cell size,bare nuclei, normal nucleoli 
# and bland chromatin
# Target variable shows high correlation with most of these variables

# %%
#Let us check for pair plots

# %%
# Relationship between variables shows come correlation. 
# Distribution of variables shows most of the values are concentrated on lower side, though range remains same for all that is 
# Between 1 to 10

# %%
corr_matrix = features_df.corr()

# %%
corr_matrix
# Out:
#                              ClumpThickness  Cell Size  Cell Shape  \
# ClumpThickness                     1.000000   0.578156    0.588956
# Cell Size                          0.578156   1.000000    0.877404
# Cell Shape                         0.588956   0.877404    1.000000
# Marginal Adhesion                  0.383573   0.640096    0.612415
# Single Epithelial Cell Size        0.432165   0.689982    0.649388
# Bare Nuclei                        0.516705   0.597223    0.623004
# Normal Nucleoli                    0.496158   0.712986    0.687331
# Bland Chromatin                    0.450853   0.657170    0.654724
# Mitoses                            0.296797   0.403911    0.381645
# Class                              0.675748   0.757623    0.757932
#
#                              Marginal Adhesion  Single Epithelial Cell Size  \
# ClumpThickness                        0.383573                     0.432165
# Cell Size                             0.640096                     0.689982
# Cell Shape                            0.612415                     0.649388
# Marginal Adhesion                     1.000000                     0.528163
# Single Epithelial Cell Size           0.528163                     1.000000
# Bare Nuclei                           0.595347                     0.486311
# Normal Nucleoli                       0.611294                     0.554625
# Bland Chromatin                       0.514134                     0.558757
# Mitoses                               0.358434                     0.434875
# Class                                 0.622371                     0.604709
#
#                              Bare Nuclei  Normal Nucleoli  Bland Chromatin  \
# ClumpThickness                  0.516705         0.496158         0.450853
# Cell Size                       0.597223         0.712986         0.657170
# Cell Shape                      0.623004         0.687331         0.654724
# Marginal Adhesion               0.595347         0.611294         0.514134
# Single Epithelial Cell Size     0.486311         0.554625         0.558757
# Bare Nuclei                     1.000000         0.612035         0.484522
# Normal Nucleoli                 0.612035         1.000000         0.607259
# Bland Chromatin                 0.484522         0.607259         1.000000
# Mitoses                         0.263648         0.279795         0.369716
# Class                           0.760736         0.707166         0.639909
#
#                               Mitoses     Class
# ClumpThickness               0.296797  0.675748
# Cell Size                    0.403911  0.757623
# Cell Shape                   0.381645  0.757932
# Marginal Adhesion            0.358434  0.622371
# Single Epithelial Cell Size  0.434875  0.604709
# Bare Nuclei                  0.263648  0.760736
# Normal Nucleoli              0.279795  0.707166
# Bland Chromatin              0.369716  0.639909
# Mitoses                      1.000000  0.360433
# Class                        0.360433  1.000000

# %% [markdown]
# Observations
# -------------------

# %% [markdown]
# 1. Clump Thickness is moderatley positively correlated with Cell Size (0.578156)
#
# 2. Clump Thickness is moderately positively correlated with Cell Shape (0.588956)
#
# 3. Cell Size is highly positvely correlated with Cell Shape (0.877404)
#
# 5. Cell Size is moderately positively correlated with Marginal Adhesion(0.640096), Single Epithelial Cell Size(0.689982), Bare Nuclei(0.598223), Normal Nucleoli(0.712986), Bland Chromatin(0.657170)
#
#
# 7. Cell Shape is moderately positively correlated with Marginal Adhesion(0.683079), Single Epithelial Cell Size(0.719668), Bare Nuclei(0.715495), Normal Nucleoli(0.735948), Bland Chromatin(0.719446)
#
# 8. Cell Shape is adequately highly correlated with Class(0.818934)
#
# 9. Bare Nuclei is adequately correlated with Class (0.820678)
#
# 10. Normal Nucleoli is moderately highly correlated with Class (0.756618)
#
# 11. Bland Chromatin is moderately highly correlated with Class (0.715540)

# %%
sns.pairplot(data = features_df, diag_kind = 'kde')
plt.show()

# %% [markdown]
# # Q5 Remove any unwanted columns or outliers, standardize variables in pre-processing step

# %%
# We could see most of the outliers are now removed.

# %%
features_df.boxplot(figsize=(15, 10))
plt.show()

# %%
features_df.shape
# Out:
# (463, 10)

# %%
cols = ['Mitoses', 'Single Epithelial Cell Size']

for col in cols:
    Q1 = features_df[col].quantile(0.25)

    Q3 =  features_df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower_limit = Q1 - (1.5 * IQR)

    upper_limit = Q3 + (1.5 * IQR)

    filter2 = features_df[col] > upper_limit

    features_df.drop(features_df[filter2].index, inplace = True)

# %%
features_df.shape
# Out:
# (393, 10)

# %% [markdown]
# # Q6 Create a covariance matrix for identifying Principal components

# %%
# PCA
# Step 1 - Create covariance matrix
cov_matrix = features_df.cov()

# %%
cov_matrix
# Out:
#                              ClumpThickness  Cell Size  Cell Shape  \
# ClumpThickness                     7.674923   4.553247    4.465545
# Cell Size                          4.553247   8.805785    7.413759
# Cell Shape                         4.465545   7.413759    8.126045
# Marginal Adhesion                  3.024777   5.113115    4.829380
# Single Epithelial Cell Size        1.966863   3.489517    3.220777
# Bare Nuclei                        5.337858   6.367392    6.528191
# Normal Nucleoli                    3.392727   5.223334    4.931830
# Bland Chromatin                    3.772356   6.241821    5.935816
# Mitoses                            0.492289   0.524225    0.457334
# Class                              1.804539   2.187945    2.149958
#
#                              Marginal Adhesion  Single Epithelial Cell Size  \
# ClumpThickness                        3.024777                     1.966863
# Cell Size                             5.113115                     3.489517
# Cell Shape                            4.829380                     3.220777
# Marginal Adhesion                     8.032884                     2.500032
# Single Epithelial Cell Size           2.500032                     3.229410
# Bare Nuclei                           6.352807                     3.219180
# Normal Nucleoli                       4.247287                     2.521317
# Bland Chromatin                       4.446312                     3.399634
# Mitoses                               0.411279                     0.306531
# Class                                 1.719959                     1.057005
#
#                              Bare Nuclei  Normal Nucleoli  Bland Chromatin  \
# ClumpThickness                  5.337858         3.392727         3.772356
# Cell Size                       6.367392         5.223334         6.241821
# Cell Shape                      6.528191         4.931830         5.935816
# Marginal Adhesion               6.352807         4.247287         4.446312
# Single Epithelial Cell Size     3.219180         2.521317         3.399634
# Bare Nuclei                    13.888975         5.536753         5.425748
# Normal Nucleoli                 5.536753         6.276068         4.922749
# Bland Chromatin                 5.425748         4.922749         9.987849
# Mitoses                         0.640773         0.332139         0.553630
# Class                           2.864712         1.765994         2.004985
#
#                               Mitoses     Class
# ClumpThickness               0.492289  1.804539
# Cell Size                    0.524225  2.187945
# Cell Shape                   0.457334  2.149958
# Marginal Adhesion            0.411279  1.719959
# Single Epithelial Cell Size  0.306531  1.057005
# Bare Nuclei                  0.640773  2.864712
# Normal Nucleoli              0.332139  1.765994
# Bland Chromatin              0.553630  2.004985
# Mitoses                      0.319871  0.196993
# Class                        0.196993  0.986966

# %% [markdown]
# # Q7 Identify eigen values and eigen vector

# %%
# Step 2- Get eigen values and eigen vector

# %%
eig_vals, eig_vectors =np.linalg.eig(cov_matrix)

# %%
eig_vals
# Out:
# array([43.04062723,  7.07823458,  4.96705983,  3.77347778,  3.16330711,
#         0.19906351,  0.267013  ,  2.26657388,  1.56256045,  1.01085917])

# %%
eig_vectors
# Out:
# array([[-2.85158606e-01, -9.87135851e-02,  8.32397201e-01,
#         -8.99320238e-02, -4.45329597e-01, -6.37737110e-02,
#         -5.01027542e-02,  2.22398749e-02, -5.06359131e-02,
#         -3.59146805e-03],
#        [-3.99893365e-01,  2.61970735e-01,  6.17200528e-02,
#         -3.31629646e-01,  3.83750116e-01, -2.60443880e-02,
#         -3.78534471e-02,  1.31745327e-01,  4.84737391e-02,
#          6.98990103e-01],
#        [-3.86216634e-01,  1.88082872e-01,  8.40181672e-02,
#         -2.54851037e-01,  4.03695118e-01, -5.06269342e-02,
#          2.83065456e-02,  1.78312733e-01,  2.54961077e-01,
#         -6.93050333e-01],
#        [-3.25650528e-01, -1.38425562e-01, -5.02593075e-01,
#         -4.83787252e-01, -5.94570176e-01, -2.66562446e-03,
#         -9.64927136e-03,  1.81722640e-01,  2.48620787e-02,
#         -2.97496898e-02],
#        [-1.93338592e-01,  1.33834031e-01, -6.00962931e-02,
#          2.51893444e-02,  9.63364094e-02, -1.11756385e-02,
#         -4.56030959e-02,  7.47046675e-02, -9.49544724e-01,
#         -1.47517328e-01],
#        [-4.60539424e-01, -7.51155487e-01, -9.71371591e-02,
#          3.79944763e-01,  2.21491932e-01, -9.53582570e-02,
#         -3.97151778e-02,  7.35310132e-02,  2.54767275e-02,
#          6.39545177e-02],
#        [-3.11642322e-01,  8.32930650e-02, -8.90857116e-02,
#         -4.91320480e-02, -1.78821888e-02, -5.45883012e-02,
#          2.28550779e-02, -9.38133178e-01,  9.63246913e-03,
#         -3.97800393e-02],
#        [-3.71744330e-01,  5.25681840e-01, -1.42826841e-01,
#          6.58900155e-01, -2.80461470e-01, -3.15397859e-02,
#         -3.49517508e-02,  1.56067977e-01,  1.58129134e-01,
#          2.60533913e-02],
#        [-3.16127128e-02, -1.74711428e-03,  2.00184358e-02,
#          2.08636593e-02, -2.32078821e-02, -1.83470683e-01,
#          9.78896212e-01,  3.99318259e-02, -4.56198622e-02,
#          4.52541792e-02],
#        [-1.33295883e-01, -4.07659309e-02,  4.31622853e-02,
#          3.07190770e-02,  8.80690270e-03,  9.72538013e-01,
#          1.77549292e-01, -1.72274890e-02, -3.25755816e-05,
#         -5.95101377e-03]])

# %% [markdown]
# # Q8 Find variance and cumulative variance by each eigen vector

# %%
eig_vectors.var()
# Out:
# 0.09951937762767481

# %%
total_eigen_vals = sum(eig_vals)

var_explained = [(i/total_eigen_vals * 100) for i in sorted(eig_vals, reverse = True)]

print(var_explained)

print(np.cumsum(var_explained))
# Out:
# [63.92604980419202, 10.512941043921826, 7.377320792895226, 5.604554209284447, 4.698298814213461, 3.366426653673131, 2.32079139728324, 1.5013775963385572, 0.39658079590952444, 0.2956588922885669]
# [ 63.9260498   74.43899085  81.81631164  87.42086585  92.11916466
#   95.48559132  97.80638272  99.30776031  99.70434111 100.        ]

# %% [markdown]
# # Q9 Use PCA command from sklearn and find Principal Components. Transform data to components formed

# %%
X = features_df.drop('Class', axis = 1)

y = features_df['Class']

# %%
pca = PCA()
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
X_pca = pca.transform(X)

# %%
X_pca.shape
# Out:
# (393, 9)

# %% [markdown]
# # Q10 Find correlation between components and features

# %%
pca.components_
# Out:
# array([[ 0.28707839,  0.40384401,  0.38989863,  0.32906283,  0.19525448,
#          0.46379326,  0.31450588,  0.37554809,  0.03184199],
#        [-0.09754812,  0.25938942,  0.18576906, -0.14361238,  0.13246926,
#         -0.75464215,  0.08116878,  0.52387247, -0.00179459],
#        [-0.83630639, -0.06412541, -0.08640266,  0.49762578,  0.0597781 ,
#          0.09143669,  0.08793147,  0.14598851, -0.02010062],
#        [ 0.08324011,  0.33069325,  0.25369839,  0.48393401, -0.02532595,
#         -0.38349088,  0.04911283, -0.65923785, -0.02108988],
#        [-0.44418532,  0.38369983,  0.40381051, -0.5953257 ,  0.09650894,
#          0.22313875, -0.01804462, -0.27934313, -0.02313335],
#        [ 0.02065352,  0.13113962,  0.17763416,  0.18240806,  0.0743802 ,
#          0.07114617, -0.93876313,  0.15519486,  0.0399173 ],
#        [ 0.05063866, -0.04847257, -0.25496017, -0.0248628 ,  0.9495452 ,
#         -0.02547288, -0.00962988, -0.15812791,  0.04561971],
#        [-0.00406465,  0.69879729, -0.69329009, -0.02970804, -0.14762835,
#          0.0632955 , -0.04013295,  0.02582467,  0.04532212],
#        [-0.03775055, -0.03265955,  0.03698601, -0.00913671, -0.04285028,
#         -0.02184584,  0.03238   , -0.0287176 ,  0.99592683]])

# %%
pca.explained_variance_
# Out:
# array([42.27997741,  7.06662357,  4.95797999,  3.77000454,  3.16306984,
#         2.26594406,  1.56256045,  1.0108298 ,  0.26482111])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.63730515, 0.1065184 , 0.07473387, 0.05682698, 0.04767838,
#        0.0341556 , 0.02355318, 0.01523669, 0.00399177])

# %%
corr_df = pd.DataFrame(data = pca.components_, columns = X.columns)

# %%
corr_df.head()
# Out:
#    ClumpThickness  Cell Size  Cell Shape  Marginal Adhesion  \
# 0        0.287078   0.403844    0.389899           0.329063
# 1       -0.097548   0.259389    0.185769          -0.143612
# 2       -0.836306  -0.064125   -0.086403           0.497626
# 3        0.083240   0.330693    0.253698           0.483934
# 4       -0.444185   0.383700    0.403811          -0.595326
#
#    Single Epithelial Cell Size  Bare Nuclei  Normal Nucleoli  Bland Chromatin  \
# 0                     0.195254     0.463793         0.314506         0.375548
# 1                     0.132469    -0.754642         0.081169         0.523872
# 2                     0.059778     0.091437         0.087931         0.145989
# 3                    -0.025326    -0.383491         0.049113        -0.659238
# 4                     0.096509     0.223139        -0.018045        -0.279343
#
#     Mitoses
# 0  0.031842
# 1 -0.001795
# 2 -0.020101
# 3 -0.021090
# 4 -0.023133

# %%
sns.heatmap(corr_df)
plt.show()

# %% [markdown]
# # Popularity Based Recommendation System

# %% [markdown]
# ### About Dataset

# %% [markdown]
# Anonymous Ratings on jokes.

# %% [markdown]
# 1. Ratings are real values ranging from -10.00 to +10.00 (the value "99" corresponds to "null" = "not rated").
#
# 2. One row per user
#
# 3. The first column gives the number of jokes rated by that user. The next 100 columns give the ratings for jokes 01 - 100.

# %% [markdown]
# # Q11 Read the dataset(jokes.csv)

# %%
jokes_df = pd.read_excel('jokes.xlsx')

# %%
jokes_df.head()
# Out:
#    NumJokes  Joke1  Joke2  Joke3  Joke4  Joke5  Joke6  Joke7  Joke8  Joke9  \
# 0        74  -7.82   8.79  -9.66  -8.16  -7.52  -8.50  -9.85   4.17  -8.98
# 1       100   4.08  -0.29   6.36   4.37  -2.38  -9.66  -0.73  -5.34   8.88
# 2        49  99.00  99.00  99.00  99.00   9.03   9.27   9.03   9.27  99.00
# 3        48  99.00   8.35  99.00  99.00   1.80   8.16  -2.82   6.21  99.00
# 4        91   8.50   4.61  -4.17  -5.39   1.36   1.60   7.04   4.61  -0.44
#
#    ...  Joke91  Joke92  Joke93  Joke94  Joke95  Joke96  Joke97  Joke98  \
# 0  ...    2.82   99.00   99.00   99.00   99.00   99.00   -5.63   99.00
# 1  ...    2.82   -4.95   -0.29    7.86   -0.19   -2.14    3.06    0.34
# 2  ...   99.00   99.00   99.00    9.08   99.00   99.00   99.00   99.00
# 3  ...   99.00   99.00   99.00    0.53   99.00   99.00   99.00   99.00
# 4  ...    5.19    5.58    4.27    5.19    5.73    1.55    3.11    6.55
#
#    Joke99  Joke100
# 0   99.00    99.00
# 1   -4.32     1.07
# 2   99.00    99.00
# 3   99.00    99.00
# 4    1.80     1.60
#
# [5 rows x 101 columns]

# %% [markdown]
# # Q12 Create a new dataframe named `ratings`, with only first 200 rows and all columns from 1(first column is 0) of dataset

# %%
ratings = jokes_df.head(200)

# %% [markdown]
# # Q13 In the dataset, the null ratings are given as 99.00, so replace all 99.00s with 0
# Hint: You can use `ratings.replace(<the given value>, <new value you wanted to change with>)`

# %%
ratings = ratings_df.replace(99.00, 0)

# %% [markdown]
# # Q14 Normalize the ratings using StandardScaler and save them in ratings_diff variable

# %%
scaler = StandardScaler()

ratings_diff = scaler.fit_transform(ratings)

# %%
ratings_diff
# Out:
# array([[ 0.17851402, -1.85701632,  1.67164929, ..., -0.02685824,
#         -0.04144395, -0.16095388],
#        [ 1.37166689,  0.78949409, -0.1802773 , ...,  0.07059963,
#         -1.36765027,  0.16746078],
#        [-0.96874834, -0.11788091, -0.12112987, ..., -0.02685824,
#         -0.04144395, -0.16095388],
#        ...,
#        [ 1.37166689,  0.46479617, -0.89412566, ..., -0.23610604,
#          0.18266036, -0.02590486],
#        [-1.24409131, -0.11788091, -0.12112987, ..., -0.02685824,
#         -0.04144395, -0.16095388],
#        [ 0.04084254,  1.12308784, -1.60593445, ..., -0.02685824,
#         -0.04144395, -0.16095388]])

# %% [markdown]
# # Q15  Find the mean for each column  in `ratings_diff` i.e, for each joke

# %%
all_mean = ratings_diff.mean(axis = 0)

all_mean
# Out:
# array([ 5.32907052e-17,  0.00000000e+00,  1.77635684e-17, -2.88657986e-17,
#        -1.33226763e-17, -2.22044605e-18, -6.66133815e-18,  6.66133815e-18,
#         1.66533454e-17, -5.32907052e-17,  8.88178420e-18, -3.55271368e-17,
#        -4.44089210e-17, -8.88178420e-18,  3.55271368e-17, -8.88178420e-18,
#        -1.19904087e-16,  1.99840144e-17,  2.55351296e-17,  8.88178420e-18,
#         2.66453526e-17,  1.11022302e-16, -1.77635684e-17, -2.66453526e-17,
#         4.44089210e-17, -1.33226763e-17, -5.32907052e-17, -1.77635684e-17,
#         8.88178420e-18,  0.00000000e+00,  0.00000000e+00,  3.55271368e-17,
#        -1.06581410e-16,  4.44089210e-18,  4.44089210e-18, -8.88178420e-18,
#         1.77635684e-17,  1.77635684e-17, -2.22044605e-17, -1.77635684e-17,
#         1.11022302e-17,  0.00000000e+00,  1.33226763e-17,  3.10862447e-17,
#        -2.66453526e-17,  8.88178420e-18, -1.33226763e-17, -1.77635684e-17,
#         7.77156117e-17, -1.77635684e-17,  7.10542736e-17, -8.88178420e-18,
#        -8.88178420e-18, -4.44089210e-18,  1.15463195e-16, -8.88178420e-18,
#         1.33226763e-17, -1.33226763e-17,  1.33226763e-17, -1.11022302e-17,
#        -4.44089210e-18,  4.44089210e-18, -2.66453526e-17,  1.99840144e-17,
#         4.44089210e-18,  7.10542736e-17, -5.77315973e-17, -1.33226763e-17,
#        -1.77635684e-17,  1.66533454e-17,  4.44089210e-18, -2.66453526e-17,
#         1.77635684e-17, -2.22044605e-17,  4.44089210e-17,  0.00000000e+00,
#         8.88178420e-18,  1.77635684e-17, -2.22044605e-17, -2.22044605e-17,
#        -5.77315973e-17,  4.44089210e-18,  8.88178420e-18, -4.44089210e-18,
#         4.44089210e-17,  2.44249065e-17,  8.88178420e-18, -3.55271368e-17,
#        -1.38777878e-17,  2.22044605e-17, -2.22044605e-17, -4.44089210e-17,
#        -3.55271368e-17,  0.00000000e+00, -1.33226763e-17,  0.00000000e+00,
#         4.44089210e-18, -2.22044605e-17,  8.88178420e-18, -1.77635684e-17,
#         5.77315973e-17])

# %% [markdown]
# # Q16 Consider all the mean ratings and find the jokes with highest mean value and display the top 10 joke IDs.

# %%
all_mean_df = pd.DataFrame(data = ratings_diff)

# %%
all_mean_df
# Out:
#           0         1         2         3         4         5         6    \
# 0    0
-0.184043 -0.175922 -0.140401 -0.233349 -0.026858 -0.041444 -0.160954
# 172 -0.184043 -0.175922  1.557662 -0.233349 -0.026858 -0.041444 -0.160954
# 173 -0.184043 -0.175922 -0.140401 -0.774225 -0.026858 -0.041444 -0.160954
# 174 -0.184043  1.983600 -0.140401 -0.233349 -0.026858 -0.041444 -0.160954
# 175 -0.184043 -0.175922 -0.140401  1.658171 -0.026858 -0.041444 -0.160954
# 176  0.110241 -1.307101  0.626249 -0.743318  0.572221 -1.874187  0.508153
# 177 -0.184043 -0.175922 -0.140401 -0.233349 -0.026858 -0.041444 -0.160954
# 178 -0.184043 -0.175922 -0.140401 -0.233349 -0.026858 -0.041444 -0.160954
# 179 -0.184043 -0.175922 -0.140401 -0.233349 -0.095652 -0.041444 -0.160954
# 180 -0.184043 -0.175922 -0.140401 -0.233349 -0.026858 -0.041444 -0.160954
# 181 -0.184043 -0.175922 -0.140401 -0.233349 -0.026858 -0.041444 -0.160954
# 182 -0.184043 -0.175922 -0.140401 -0.233349 -0.026858 -0.041444 -0.160954
# 183 -0.184043 -0.175922 -0.140401 -0.233349 -0.026858 -0.041444 -0.160954
# 184 -2.466185 -0.175922 -0.140401 -0.233349 -0.026858 -0.041444 -0.160954
# 185 -0.184043  2.056189 -0.140401 -0.233349 -0.026858 -2.082942  2.042801
# 186 -0.184043 -0.175922 -0.140401 -0.233349 -0.026858 -0.041444 -0.160954
# 187 -0.184043 -0.175922 -0.140401 -0.233349 -0.026858 -0.041444 -0.160954
# 188 -0.184043 -0.175922 -0.140401 -0.233349 -0.026858 -0.041444 -0.160954
# 189 -0.184043 -0.175922 -0.140401 -0.233349 -0.026858 -0.041444 -0.160954
# 190 -0.184043 -0.175922 -0.140401 -0.233349 -0.026858 -0.041444 -0.160954
# 191 -0.184043 -0.175922 -0.140401 -0.233349 -0.026858 -0.041444 -0.160954
# 192 -1.009192  0.689096  2.243612  1.522179  2.117215  2.595619  0.523499
# 193 -1.038043 -0.484426 -2.215065  1.281103  2.615970  2.463612  1.926167
# 194  0.753626  0.616507  0.528737  2.467939 -1.904356 -0.204150 -2.797479
# 195  1.425863  1.557140  1.036474 -0.233349 -0.611605  0.851903  0.403797
# 196 -0.184043 -0.175922 -0.140401 -0.233349 -0.026858 -0.041444 -0.160954
# 197 -0.729333  0.177949 -0.826352 -0.594963 -0.236106  0.182660 -0.025905
# 198 -0.184043 -0.175922 -0.140401 -0.233349 -0.026858 -0.041444 -0.160954
# 199 -0.184043 -0.175922 -0.140401 -0.233349 -0.026858 -0.041444 -0.160954
#
# [200 rows x 101 columns]

# %%
all_mean_df.mean(axis = 0)
# Out:
# 0      3.365364e-17
# 1     -1.110223e-17
# 2     -9.658940e-17
# 3     -4.107825e-17
# 4      3.719247e-17
# 5     -8.881784e-18
# 6     -2.636780e-18
# 7     -1.665335e-18
# 8      2.331468e-17
# 9     -4.329870e-17
# 10    -2.553513e-17
# 11    -4.551914e-17
# 12    -8.604228e-17
# 13     6.661338e-17
# 14     5.467848e-17
# 15    -2.164935e-17
# 16    -1.065814e-16
# 17     1.637579e-17
# 18     2.331468e-17
# 19    -9.159340e-18
# 20     2.997602e-17
# 21     1.065814e-16
# 22     1.720846e-17
# 23    -2.775558e-17
# 24     4.329870e-17
# 25    -3.885781e-17
# 26    -1.498801e-17
# 27    -3.996803e-17
# 28    -9.436896e-18
# 29    -5.273559e-17
#            ...
# 71     7.632783e-19
# 72    -9.325873e-17
# 73    -4.024558e-17
# 74     7.743806e-17
# 75     1.290634e-17
# 76     3.885781e-17
# 77     3.747003e-18
# 78    -2.886580e-17
# 79    -9.853229e-18
# 80    -6.938894e-17
# 81     3.941292e-17
# 82     1.243450e-16
# 83     0.000000e+00
# 84     2.498002e-17
# 85    -2.045586e-16
# 86    -1.290634e-17
# 87    -8.465451e-17
# 88     5.107026e-17
# 89     2.997602e-17
# 90    -6.369905e-17
# 91    -4.385381e-17
# 92    -3.497203e-17
# 93     8.770762e-17
# 94    -7.244205e-17
# 95     1.054712e-16
# 96     2.858824e-17
# 97    -2.137179e-17
# 98     1.198694e-16
# 99     1.840889e-16
# 100    7.549517e-17
# Length: 101, dtype: float64

# %%
new_df = pd.DataFrame(data = all_mean_df)

# %%
new_df.iloc[:,0].argsort()[:-10:-1]
# Out:
# 199     53
# 198     50
# 197     38
# 196     86
# 195    135
# 194    166
# 193     44
# 192    121
# 191    158
# Name: 0, dtype: int64
